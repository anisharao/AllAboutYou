# %%
import pandas as pd
import mysql 
from getpass import getpass
from mysql.connector import connect, Error

# %%
mood_activity = pd.read_csv("/Users/linalouis/Downloads/mood_activity.csv")

# %%
activities = pd.read_csv("/Users/linalouis/Downloads/activities.csv")
mood =pd.read_csv("/Users/linalouis/Downloads/moods.csv")

# %%
conn = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Iambeautiful@123",
    database = "All_about_you"

)
if conn.is_connected():
    cursor = conn.cursor()
    for i,row in mood.iterrows():
        #here %S means string values
        sql = "INSERT INTO moods VALUES (%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Record inserted")
        # the connection is not auto committed by default, so we must commit to save our changes
        conn.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %%
if conn.is_connected():
    cursor = conn.cursor()
    for i,row in activities.iterrows():
        #here %S means string values
        sql = "INSERT INTO activities VALUES (%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Record inserted")
        # the connection is not auto committed by default, so we must commit to save our changes
        conn.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %%
conn = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Iambeautiful@123",
    database = "All_about_you"

)
cursor = conn.cursor()
for i,row in mood_activity.iterrows():
    #here %S means string values
    sql = "INSERT INTO mood_activity VALUES (%s,%s)"
    cursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    conn.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %%
import pandas as pd
df=pd.read_csv("/Users/linalouis/Downloads/Words_score.csv")
df['words']=df['words'].str.upper()
df.to_csv("/Users/linalouis/Downloads/Word_Score_upper.csv")

# %%
conn = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Iambeautiful@123",
    database = "All_about_you"

)
word_score =pd.read_csv("/Users/linalouis/Downloads/Word_Score_upper.csv")
word_score =  pd.DataFrame(word_score, columns= ['words', 'score'])
cursor = conn.cursor()
for i,row in word_score.iterrows():
    #here %S means string values
    sql = "INSERT INTO words_score VALUES (%s,%s)"
    
    cursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    conn.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
conn = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Iambeautiful@123",
    database = "All_about_you"

)
aff_tag =pd.read_csv("/Users/linalouis/Downloads/affirmation_tag.csv")

cursor = conn.cursor()
for i,row in aff_tag.iterrows():
    #here %S means string values
    print(row)
    x=row[0]
    x.replace(',','')
    list2=x.split(' ')
    sql1 = "select sum(score) from words_score  where words in {}".format((tuple(list2)))
    cursor.execute(sql1)
    r=cursor.fetchall()
    print(r[0][0])
    sql2 = "INSERT INTO affirmation_tag VALUES (%s,%s,%s)"
    if(r[0][0]!=None):
        
        cursor.execute(sql2, (row[0],row[1],r[0][0]))
    else:
        cursor.execute(sql2, (row[0],row[1],0))
    
    print("Record inserted")
    conn.commit()
# Out:
# affirmation    I AM SUPERNATURALLY BEAUTIFUL.
# tagID                                       2
# Name: 0, dtype: object
# None
# Record inserted
# affirmation    I GLOW WITH SUPERNATURAL BEAUTY.
# tagID                                         2
# Name: 1, dtype: object
# 1
# Record inserted
# affirmation    I RADIATE SUPERNATURAL BEAUTY FROM WITHIN.
# tagID                                                   2
# Name: 2, dtype: object
# 1
# Record inserted
# affirmation    I AM SUPERNATURALLY PERFECT IN EVERY WAY.
# tagID                                                  2
# Name: 3, dtype: object
# 1
# Record inserted
# affirmation    I AM SUPERNATURALLY FLAWLESS IN EVERY WAY.
# tagID                                                   2
# Name: 4, dtype: object
# 1
# Record inserted
# affirmation    MY PRESENCE IS SUPERNATURALLY POWERFUL.
# tagID                                                2
# Name: 5, dtype: object
# None
# Record inserted
# ...
