# %%
from tkinter import *
import random
import mysql.connector
import hashlib
import pymongo
from pymongo import MongoClient
from tkinter import ttk
from datetime import datetime



client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
db = client['All_about_you']
survey_data_collection = db['Survey_data']

db = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Iambeautiful@123",
    database = "All_about_you"

)

cur = db.cursor()



def submitact():
     
    user = username.get()
    passw = password.get()
    
       
  
    login(user, passw)

def login(user,passw):
    
    cur.execute("Select password from user where email = "+"'"+user+"'")
   
    result = cur.fetchall()
    
    if(result[0][0]==hashlib.md5(passw.encode()).hexdigest()):
        Yes_Screen2()
    else:
        print("fail")

        
    
    

def Register():
    global ws1
    ws1 = Toplevel(ws)
    ws1.title('Registration Page')
    ws1.geometry('1000x1000')
    ws1.config(bg='#0B5A81')
    
    left_frame1 = Frame(
    ws1, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )

    f = ('Times', 14)
      
    Label(left_frame1,text='User Registration Form', bg='light blue').grid(row=0, column=1)
    
    global FirstName
    FirstName= StringVar()
    Label(left_frame1, text="First Name", bg='#CCCCCC',font=f).grid(row=1, column=0, sticky=W, pady=10)
    FirstName = Entry(left_frame, font=f, textvariable=FirstName)
        
    global LastName
    LastName= StringVar()
    Label(left_frame1,text="Last Name", 
    bg='#CCCCCC',
    font=f).grid(row=2, column=0, sticky=W, pady=10)
    
    global UserName1
    UserName1= StringVar()
    Label(left_frame1,text="User Name (Email)", 
    bg='#CCCCCC',
    font=f).grid(row=3, column=0, sticky=W, pady=10)
    
    global Gender
    Gender= StringVar()
    Label(left_frame1,text="Gender", 
    bg='#CCCCCC',
    font=f
    ).grid(row=4, column=0, pady=10)
    
    global DateOfBirth
    DateOfBirth= StringVar()
    Label(left_frame1,text="Date of Birth", 
    bg='#CCCCCC',
    font=f
    ).grid(row=5, column=0, pady=10)
    
    global Password1 
    Password1= StringVar()
    Label(left_frame1,text="Password", 
    bg='#CCCCCC',
    font=f
    ).grid(row=6, column=0, pady=10)

#****** Entries
    FirstName = Entry(
    left_frame1, 
    font=f, textvariable=FirstName)
    
    LastName = Entry(
    left_frame1, 
    font=f, textvariable=LastName)
    
    UserName1 = Entry(
    left_frame1, 
    font=f, textvariable=UserName1   )
    
    Gender = Entry(
    left_frame1, 
    font=f, textvariable=Gender)
    
    DateOfBirth = Entry(
    left_frame1, 
    font=f, textvariable=DateOfBirth
    )
    Password1= Entry(
    left_frame1, 
    font=f,
    show='*', textvariable=Password1
    )
    Submit = Button(left_frame1, width=15, 
    text='Register', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Register_Submit
    )
    
    FirstName.grid(row=1, column=1, pady=10, padx=20)
    LastName.grid(row=2, column=1, pady=10, padx=20)
    UserName1.grid(row=3, column=1, pady=10, padx=20)
    Gender.grid(row=4, column=1, pady=10, padx=20)
    DateOfBirth.grid(row=5, column=1, pady=10, padx=20)
    Password1.grid(row=6, column=1, pady=10, padx=20)
    Submit.grid(row=7, column=1, pady=10, padx=20)
    left_frame1.pack()
    
    
def Register_Submit():
    FirstName1 = StringVar()
    LastName1 =StringVar()
    Gender1 =StringVar()
    DOB =StringVar()
    Password_R =StringVar()
    UserName_R =StringVar()
    
    FirstName1 = FirstName.get()
    LastName1 = LastName.get()
    Gender1 = Gender.get()
    DOB = DateOfBirth.get()
    Password_R = Password1.get()
    UserName_R = UserName1.get()
    
    cur.execute("Insert into user(first_name, last_name, gender, email, dateofbirth, password) values(%s,%s,%s,%s,%s,%s)",
               (FirstName1,LastName1, Gender1, UserName_R, DOB, hashlib.md5(Password_R.encode()).hexdigest()))
    
    db.commit()
    
    left_frame2 = Frame(
    ws1, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )
    
    Label(left_frame2, text='Registration Complete', bg='light blue').grid(row=7, column=1)
    Label(left_frame2, text='Do you want to Login?', bg='light blue').grid(row=8, column=1)
    
    Yes_btn = Button(left_frame2, width=15, 
    text='Yes', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Yes_Screen
    )
    
    No_btn = Button(left_frame2, width=15, 
    text='No', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    
    )
    
    Yes_btn.grid(row=9, column=0, pady=10, padx=20)
    No_btn.grid(row=9, column=1, pady=10, padx=20)
    
    left_frame2.pack()
    
    
def Yes_Screen2():
    global ws2
    ws2 = Toplevel(ws)
    ws2.title('User questions page')
    ws2.geometry('1000x1000')
    ws2.config(bg='#0B5A81')
    
    left_frame3 = Frame(
    ws2, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )

    f = ('Times', 14)
      
    
    global ans1
    ans1 = StringVar()
    
    global Ans1
    Ans1 = StringVar()
    global ans2
    ans2 = StringVar()
    global Ans2
    Ans2= StringVar()
    
    global ans3
    ans3 = StringVar()
    
    global Ans3
    Ans3= StringVar()
    
    global mood
    mood= StringVar()
    
    global mood1
    mood1 = StringVar(ws2,"1")
    #mood1.set("ANGRY")
    
 
    
    Label(left_frame3,text='List any 3 words that describe your mood', bg='light blue').grid(row=0, column=1)
    #5 moods - agry, awful, happy, confused, scared -- 3 text boxes
    
    ans1 = Entry(
    left_frame3, 
    font=f, textvariable=ans1)
    
    ans2 = Entry(
    left_frame3, 
    font=f, textvariable=ans2)
    
    ans3 = Entry(
    left_frame3, 
    font=f, textvariable=ans3   )
    
    
    
    
    ans1.grid(row=1, column=1, pady=10, padx=20)
    ans2.grid(row=2, column=1, pady=10, padx=20)
    ans3.grid(row=3, column=1, pady=10, padx=20)
    
    Label(left_frame3,text='Answer in 1 word adjective and do not enter special characters', bg='light blue').grid(row=5, column=1)
   
    
    Label(left_frame3,text='Which of the moods best describe your current state of mind', bg='light blue').grid(row=7, column=1)
    R1 = Radiobutton(left_frame3, text="ANGRY", variable=mood1, value="ANGRY")
    R1.grid(row=8, column=1)
    R2 = Radiobutton(left_frame3, text="AWFUL", variable=mood1, value="AWFUL")
    R2.grid(row=9, column=1)
    R3 = Radiobutton(left_frame3, text="HAPPY", variable=mood1, value="HAPPY")
    R3.grid(row=10, column=1)    
    R4 = Radiobutton(left_frame3, text="CONFUSED", variable=mood1, value="CONFUSED")
    R4.grid(row=11, column=1)
    R5 = Radiobutton(left_frame3, text="SCARED", variable=mood1, value="SCARED")
    R5.grid(row=12, column=1)
    #keep everything upper case
    
    Submit1 = Button(left_frame3, width=15, 
    text='Submit', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Submit1_Questions)
    
    Submit1.grid(row=13, column=1)
    
    left_frame3.pack()
    
def Yes_Screen():
    global ws2
    ws2 = Toplevel(ws)
    ws2.title('User questions page')
    ws2.geometry('1000x1000')
    ws2.config(bg='#0B5A81')
    
    left_frame3 = Frame(
    ws2, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )

    f = ('Times', 14)
      
    
    global ans1
    ans1 = StringVar()
    
    global Ans1
    Ans1 = StringVar()
    global ans2
    ans2 = StringVar()
    global Ans2
    Ans2= StringVar()
    
    global ans3
    ans3 = StringVar()
    
    global Ans3
    Ans3= StringVar()
    
    global mood
    mood= StringVar()
    
    global mood1
    mood1 = StringVar(ws2,"1")
    #mood1.set("ANGRY")
    
 
    
    Label(left_frame3,text='List any 3 words that describe your mood', bg='light blue').grid(row=0, column=1)
    #5 moods - agry, awful, happy, confused, scared -- 3 text boxes
    
    ans1 = Entry(
    left_frame3, 
    font=f, textvariable=ans1)
    
    ans2 = Entry(
    left_frame3, 
    font=f, textvariable=ans2)
    
    ans3 = Entry(
    left_frame3, 
    font=f, textvariable=ans3   )
    
    
    
    
    ans1.grid(row=1, column=1, pady=10, padx=20)
    ans2.grid(row=2, column=1, pady=10, padx=20)
    ans3.grid(row=3, column=1, pady=10, padx=20)
    
    Label(left_frame3,text='Answer in 1 word adjective and do not enter special characters', bg='light blue').grid(row=5, column=1)
   
    
    Label(left_frame3,text='Which of the moods best describe your current state of mind', bg='light blue').grid(row=7, column=1)
    R1 = Radiobutton(left_frame3, text="ANGRY", variable=mood1, value="ANGRY")
    R1.grid(row=8, column=1)
    R2 = Radiobutton(left_frame3, text="AWFUL", variable=mood1, value="AWFUL")
    R2.grid(row=9, column=1)
    R3 = Radiobutton(left_frame3, text="HAPPY", variable=mood1, value="HAPPY")
    R3.grid(row=10, column=1)    
    R4 = Radiobutton(left_frame3, text="CONFUSED", variable=mood1, value="CONFUSED")
    R4.grid(row=11, column=1)
    R5 = Radiobutton(left_frame3, text="SCARED", variable=mood1, value="SCARED")
    R5.grid(row=12, column=1)
    #keep everything upper case
    
    Submit1 = Button(left_frame3, width=15, 
    text='Submit', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Submit1_Questions)
    
    Submit1.grid(row=13, column=1)
    
    left_frame3.pack()
def Submit1_Questions():
    global ws3
    ws3 = Toplevel(ws2)
    ws3.title('User affirmations page')
    ws3.geometry('1000x1000')
    ws3.config(bg='#0B5A81')
    
    left_frame4 = Frame(
    ws3, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )

    f = ('Times', 14)
      
    Ans1= ans1.get().upper()
    Ans2 =ans2.get().upper()
    Ans3= ans3.get().upper()
    mood = mood1.get()
    list1={Ans1,Ans2,Ans3}
    sql1 = "select sum(score) from words_score  where words in {}".format((tuple(list1)))
    cur.execute(sql1)
    score_list = cur.fetchall()
    sql2 = "select feeling from score_feeling  where score = %(x)s"
    cur.execute(sql2,{'x':score_list[0][0]})
    feeling = cur.fetchall()
  
    Label(left_frame4,text=("It seems you are feeling "+feeling[0][0]), bg='white').grid(row=1, column=1)
    #print(mood)
    sql3 = "select c.tag,c.tagID from moods a left join mood_tag b on a.moodID=b.moodID left join tags as c on b.tagID=c.tagID where a.moodname = %(x)s"
    cur.execute(sql3,{'x':mood})
    tag = cur.fetchall()
    
    Label(left_frame4,text=("Here's something to make you feel "+tag[0][0]+"\nSince you are in a "+mood+" mood"+"\nRepeat this Affirmation to boost your mood!"), bg='white').grid(row=2, column=1)
    #Label(left_frame4,text=(tag[0][0]), bg='light green').grid(row=2, column=1)
    sql4 = "select affirmation,aff_score from affirmation_tag where tagID = %(x)s"
    cur.execute(sql4,{'x':tag[0][1]})
    aff = cur.fetchall()
    aff_score = 0
    aff_list = {}
    i=0
    
  
    print("Feeling score of user:",score_list[0][0])
    for j in aff:
        
        
        if(score_list[0][0]<0):
            if(abs(score_list[0][0])==j[1]):
                print(j[0],j[1])
                aff_list[i] = j[0]
                aff_score = j[1]
                i=i+1
        else:
            aff_list[i] = j[0]
            i=i+1
                             
    
    random.shuffle(aff_list)
    print("Affirmation selected with score:\n", aff_list[0],aff_score)
    Label(left_frame4,text=aff_list[0], bg='light green').grid(row=3, column=1)
    
    sql3 = "select c.activity,c.actID from moods a left join mood_activity b on a.moodID=b.moodID left join activities as c on b.actID=c.actID where a.moodname = %(x)s"
    cur.execute(sql3,{'x':mood})
    activity = cur.fetchall()
    Label(left_frame4,text='Here are some suggested activites to make you feel better!', bg='white').grid(row=4, column=1)
    k=5
    for i in activity:
        Label(left_frame4,text=i[0], bg='yellow').grid(row=k, column=1)
        k=k+1
    print(Ans1)
    print(Ans2)
    print(Ans3)
    print(mood)
    
    Submit1 = Button(left_frame4, width=15, 
    text='Take a Survey!', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Survey)
    
    Submit1.grid(row=25, column=1)
    left_frame4.pack()
    

ws = Tk()
ws.title('All About You')
ws.config(bg='#0B5A81')

f = ('Times', 14)

username = StringVar()
password =StringVar()


left_frame = Frame(
    ws, 
    bd=2, 
    bg='#CCCCCC',   
    relief=SOLID, 
    padx=10, 
    pady=10
    )

Label(
    left_frame, 
    text="Enter Email", 
    bg='#CCCCCC',
    font=f).grid(row=0, column=0, sticky=W, pady=10)

Label(
    left_frame, 
    text="Enter Password", 
    bg='#CCCCCC',
    font=f
    ).grid(row=1, column=0, sticky=W, pady=10)

username = Entry(
    left_frame, 
    font=f, 
    )
password = Entry(
    left_frame, 
    font=f,
    show='*', 
    )
login_btn = Button(
    left_frame, 
    width=15, 
    text='Login', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=submitact
    )

Register_btn = Button(
    left_frame, 
    width=25,
    text='New User Registration', 
    font=f, 
    relief=SOLID,
    cursor='hand2',
    command=Register
    )

username.grid(row=0, column=1, pady=10, padx=20)
password.grid(row=1, column=1, pady=10, padx=20)
login_btn.grid(row=2, column=1, pady=10, padx=20)
Register_btn.grid(row=2, column=0, pady=10, padx=20)
left_frame.pack()

# Getting Datetime from timestamp
# date_time = datetime.fromtimestamp(1887639468)
# print("Datetime from timestamp:", date_time)



def insertformdetails():
#def insertformdetails(ct,Age_ip,Gender_ip,Country_ip,State_ip,Self_employed_ip,Family_history_ip,Treatment_ip,Work_interfere_ip,No_of_emp_ip,Remote_work_ip,Tech_company_ip,Benefits_ip,Care_options_ip,Wellness_prg_ip,Seek_help_ip,Anonymity_ip,Leave_ip,Mental_health_cons_ip,Physical_health_cons_ip, Coworkers_ip,Supervisor_ip, Mental_health_int_ip,Physical_health_int_ip,MentalvsPhysical_ip,Observed_cons_ip,Comments_ip):
    Age_ip = int(Age.get())
    print(Age_ip)
    Gender_ip = Gender.get()
    Country_ip = Country.get()
    State_ip = State.get()
    Self_employed_ip = Self_employed.get()
    Family_history_ip = Family_history.get()
    Treatment_ip = Treatment.get()
    Work_interfere_ip = Work_interfere.get()
    No_of_emp_ip = int(No_of_emp.get())
    Remote_work_ip  = Remote_work.get()
    Tech_company_ip = Tech_company.get()
    Benefits_ip = Benefits.get()
    ct = datetime.now()
    Care_options_ip=Care_options.get()
    Wellness_prg_ip=Wellness_prg.get()
    Seek_help_ip=  Seek_help.get()
    Anonymity_ip=  Anonymity.get()
    Leave_ip= Leave.get()
    Mental_health_cons_ip =Mental_health_cons.get()
    Physical_health_cons_ip   =Physical_health_cons.get()
    Coworkers_ip  =Coworkers.get()
    Supervisor_ip = Supervisor.get()
    Mental_health_int_ip = Mental_health_int.get()
    Physical_health_int_ip = Physical_health_int.get()
    MentalvsPhysical_ip = MentalvsPhysical.get()
    Observed_cons_ip =  Observed_cons.get()
    Comments_ip = Comments.get() 
    result = survey_data_collection.insert_one({'Timestamp':ct,'Age':Age_ip,'Gender':Gender_ip,'Country':Country_ip,'State':State_ip,'self_employed':Self_employed_ip,'family_history':Family_history_ip,'treatment':Treatment_ip,'work_interfere':Work_interfere_ip,'remote_work':Remote_work_ip,'Tech_company':Tech_company_ip,'Benefits':Benefits_ip,'Timestamp':ct,'care_options':Care_options_ip,'wellness_program':Wellness_prg_ip,'seek_help':Seek_help_ip,'anonymity':Anonymity_ip,'leave':Leave_ip,'mental_health_consequence':Mental_health_cons_ip,'phys_health_consequence':Physical_health_cons_ip,'coworker':Coworkers_ip,'supervisor':Supervisor_ip,'mental_helath_interview': Mental_health_int_ip,'phys_helath_interview':Physical_health_int_ip,'mental_vs_physical':MentalvsPhysical_ip,'obs_consequence':Observed_cons_ip,'comments':Comments_ip})
    print(result)
    
def Survey():
    global ws4
    ws4 = Toplevel(ws3)
    
    ws4.title('Survey Page')
    ws4.config(bg='#21618C')
    f = ('Times', 14) #font
    global Age
    Age = IntVar()
    global Gender
    Gender = StringVar()
    global Country
    Country = StringVar()
    global State
    State = StringVar()
    global Self_employed
    Self_employed=StringVar()
    global Family_history
    Family_history=StringVar()
    global Treatment 
    Treatment=StringVar()
    global Work_interfere
    Work_interfere=StringVar()
    global No_of_emp
    No_of_emp=IntVar()
    global Remote_work
    Remote_work=StringVar()
    global Tech_company
    Tech_company=StringVar()
    global Benefits
    Benefits=StringVar()

    global Care_options 
    Care_options = StringVar()
    global Wellness_prg
    Wellness_prg = StringVar()
    global Seek_help
    Seek_help = StringVar()
    global Anonymity 
    Anonymity = StringVar()
    global Leave
    Leave = StringVar()
    global Mental_health_cons
    Mental_health_cons = StringVar()
    global Physical_health_cons
    Physical_health_cons = StringVar()
    global Coworkers
    Coworkers = StringVar()
    global Supervisor
    Supervisor = StringVar()
    global Mental_health_int
    Mental_health_int = StringVar()
    global  Physical_health_int  

    Physical_health_int = StringVar()
    global MentalvsPhysical
    MentalvsPhysical = StringVar()
    global Observed_cons
    Observed_cons = StringVar()
    global Comments
    Comments = StringVar()    

    #scrollbar configuration
    # Create a main frame that holds everything.
    main_frame = Frame(ws4)
    main_frame.pack(fill=BOTH, expand=1)
    # Create a canvas
    my_canvas = Canvas(main_frame)
    my_canvas.pack(side=LEFT, fill=BOTH, expand=1)
    # Add a scrollbar to the canvas
    my_scrollbar = ttk.Scrollbar(main_frame, orient=VERTICAL, command=my_canvas.yview)
    my_scrollbar.pack(side=RIGHT, fill=Y)
    # Configure the Canvas.
    my_canvas.configure(yscrollcommand=my_scrollbar.set)
    my_canvas.bind('<Configure>', lambda e: my_canvas.configure(scrollregion = my_canvas.bbox("all")))
    #Create another frmae inside the canvas

    left_frame = Frame(
        my_canvas,
        bd=2, 
        bg='#CCCCCC',   
        relief=SOLID, 
        padx=10, 
        pady=10,
        )

    # Add that new frame to a window in the canvas
    my_canvas.create_window((0,0), window=left_frame, anchor='nw')

    Label(
        left_frame, 
        text="Enter Age", 
        bg='#CCCCCC',
        font=f).grid(row=0, column=0, sticky=W, pady=10)

    Label(
        left_frame, 
        text="Enter Gender (Male/Female)", 
        bg='#CCCCCC',
        font=f
        ).grid(row=1, column=0, sticky=W, pady=10)

    Label(
        left_frame, 
        text="Enter Country (full name)", 
        bg='#CCCCCC',
        font=f
        ).grid(row=2, column=0, sticky=W, pady=10)

    Label(
        left_frame, 
        text="Enter State (short form)", 
        bg='#CCCCCC',
        font=f
        ).grid(row=3, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Are you Self Employed?(Yes/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=4, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you have a family history of mental illness?(Yes/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=5, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Any Treatment taken?(Yes/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=6, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="If you have a mental health condition, do you feel that it interferes with your work? (Sometimes/Often/Rarely/Never)",
        bg='#CCCCCC',
        font=f
        ).grid(row=7, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="No. of employees in your organization (Range/More than {a number})",
        bg='#CCCCCC',
        font=f
        ).grid(row=8, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you work remotely?(Yes/no)",
        bg='#CCCCCC',
        font=f
        ).grid(row=9, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Is your employer a tech company/organization?(Yes/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=10, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Does your employer provide mental health benefits?(Yes/No/Don't know)",
        bg='#CCCCCC',
        font=f
        ).grid(row=11, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you know the options for mental health care your employer provides?(Yes/No/Not sure)",
        bg='#CCCCCC',
        font=f).grid(row=12, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Has your employer ever discussed mental health as part of an employee wellness program?(Yes/No/Don't know)",
        bg='#CCCCCC',
        font=f
        ).grid(row=13, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Does your employer provide resources to learn more about mental health issues and how to seek help?(Yes/no/Don't know)",
        bg='#CCCCCC',
        font=f
        ).grid(row=14, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?(Yes/No/Don't know)",
        bg='#CCCCCC',
        font=f
        ).grid(row=15, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="How easy is it for you to take medical leave for a mental health condition?(Don't know/Somewhat easy/Somewhat difficult/Very difficult/Very easy)",
        bg='#CCCCCC',
        font=f
        ).grid(row=16, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you think that discussing a mental health issue with your employer would have negative consequences?(Yes/No/Maybe)",
        bg='#CCCCCC',
        font=f
        ).grid(row=17, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you think that discussing a physical health issue with your employer would have negative consequences?(Yes/No/Maybe)",
        bg='#CCCCCC',
        font=f
        ).grid(row=18, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Would you be willing to discuss a mental health issue with your coworkers?(Yes/Some of them/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=19, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Would you be willing to discuss a mental health issue with your direct supervisor(s)?(Yes/Some of them/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=20, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Would you bring up a mental health issue with a potential employer in an interview?(Yes/No/Maybe)",
        bg='#CCCCCC',
        font=f
        ).grid(row=21, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Would you bring up a physical health issue with a potential employer in an interview?(Yes/No/Maybe)",
        bg='#CCCCCC',
        font=f
        ).grid(row=22, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Do you feel that your employer takes mental health as seriously as physical health?(Yes/No/Don't know)",
        bg='#CCCCCC',
        font=f
        ).grid(row=23, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?(Yes/No)",
        bg='#CCCCCC',
        font=f
        ).grid(row=24, column=0, sticky=W, pady=10)

    Label(
        left_frame,
        text="Any additional notes or comments",
        bg='#CCCCCC',
        font=f
        ).grid(row=25, column=0, sticky=W, pady=10)



    Age = Entry(          
        left_frame,
        font=f,
        )

    Gender = Entry(
        left_frame,
        font=f,
        )

    Country = Entry(
        left_frame,
        font=f,
        )

    State = Entry(
        left_frame,
        font=f,
        )

    Self_employed = Entry(
        left_frame,
        font=f,
        )

    Family_history = Entry(
        left_frame,
        font=f,
        )

    Treatment = Entry(
        left_frame,
        font=f,
        )

    Work_interfere = Entry(
        left_frame,
        font=f,
        )

    No_of_emp = Entry(
        left_frame,
        font=f,
        )

    Remote_work = Entry(
        left_frame,
        font=f,
        )

    Tech_company = Entry(
        left_frame,
        font=f,
        )

    Benefits = Entry(
        left_frame,
        font=f,
        )

    Care_options = Entry(
        left_frame,
        font=f,
        )

    Wellness_prg = Entry(
        left_frame,
        font=f,
        )

    Seek_help = Entry(
        left_frame,
        font=f,
        )

    Anonymity = Entry(
        left_frame,
        font=f,
        )

    Leave = Entry(
        left_frame,
        font=f,
        )

    Mental_health_cons = Entry(
        left_frame,
        font=f,
        )

    Physical_health_cons = Entry(
        left_frame,
        font=f,
        )

    Coworkers = Entry(
        left_frame,
        font=f,
        )

    Supervisor = Entry(
        left_frame,
        font=f,
        )

    Mental_health_int = Entry(
        left_frame,
        font=f,
        )

    Physical_health_int = Entry(
        left_frame,
        font=f,
        )

    MentalvsPhysical = Entry(
        left_frame,
        font=f,
        )

    Observed_cons = Entry(
        left_frame,
        font=f,
        )

    Comments = Entry(
        left_frame,
        font=f,
        )
    
   
    Age.grid(row=0, column=1, pady=10, padx=20)
    Gender.grid(row=1, column=1, pady=10, padx=20)
    Country.grid(row=2, column=1, pady=10, padx=20)
    State.grid(row=3, column=1, pady=10, padx=20)
    Self_employed.grid(row=4, column=1, pady=10, padx=20)
    Family_history.grid(row=5, column=1, pady=10, padx=20)
    Treatment.grid(row=6, column=1, pady=10, padx=20)
    Work_interfere.grid(row=7, column=1, pady=10, padx=20)
    No_of_emp.grid(row=8, column=1, pady=10, padx=20)
    Remote_work.grid(row=9, column=1, pady=10, padx=20)
    Tech_company.grid(row=10, column=1, pady=10, padx=20)
    Benefits.grid(row=11, column=1, pady=10, padx=20)
    Care_options.grid(row=12,column=1, pady=10, padx=20)
    Wellness_prg.grid(row=13,column=1, pady=10, padx=20)
    Seek_help.grid(row=14 ,column=1, pady=10, padx=20)
    Anonymity.grid(row=15 ,column=1, pady=10, padx=20)
    Leave.grid(row=16 ,column=1, pady=10, padx=20)
    Mental_health_cons.grid(row=17,column=1, pady=10, padx=20)
    Physical_health_cons.grid(row=18,column=1, pady=10, padx=20)
    Coworkers.grid(row=19,column=1, pady=10, padx=20)
    Supervisor.grid(row=20,column=1, pady=10, padx=20)
    Mental_health_int .grid(row=21,column=1, pady=10, padx=20)
    Physical_health_int.grid(row=22,column=1, pady=10, padx=20)
    MentalvsPhysical .grid(row=23,column=1, pady=10, padx=20)
    Observed_cons.grid(row=24,column=1, pady=10, padx=20)
    Comments.grid(row=25,column=1, pady=10, padx=20)
    
    

   
    Submit_button = Button(
        left_frame, 
        width=15, 
        text='Submit', 
        font=f, 
        relief=SOLID,
        cursor='hand2',
        command=insertformdetails
        )
    Submit_button.grid(row=26, column=1, pady=10, padx=20)
    

        
ws.mainloop()
# Out:
# Feeling score of user: 1
# Affirmation selected with score:
#  I ALWAYS AWAKEN RESTED AND ENERGIZED. 0
# JOLLY
# GOOD
# GOOFY
# CONFUSED
